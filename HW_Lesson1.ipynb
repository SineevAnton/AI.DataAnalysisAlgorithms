# %% [markdown]
# ## Урок 1. Алгоритм линейной регрессии. Градиентный спуск
# ___

# %% [markdown]
# __Задача:__ предсказание баллов ЕГЭ ученика в зависимости от кол-ва лет стажа его репетитора

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

# %%
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

# %% [markdown]
# ### 1. Подберите скорость обучения (alpha) и количество итераций
# ___

# %%
n = X.shape[0]

# Перебираем циклом заданные в списках скорости обучения и количество итераций
alphas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 5e-4, 1e-4]
n_iters = [10, 100, 250, 500, 800, 1000]

best_error = np.inf
best_params = {}


for alpha in alphas:
    for n_iter in n_iters:
        W = np.array([1, 0.5])
        curr_alpha = alpha
        
        for i in range(n_iter):
            y_pred = np.dot(X, W)
            err = calc_mse(y, y_pred)
            for k in range(W.shape[0]):
                W[k] -= curr_alpha * (1/n * 2 * X[:, k] @ (y_pred - y))
            if i % 10 == 0:
                curr_alpha /= 1.1
                print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
                
        if err < best_error:
            best_error = err
            best_params = {
                'alpha': alpha,
                'n_iter': n_iter
            }
print(f'Лучшая ошибка {best_error} с параметрами {best_params}')
# Out:
# Iteration #0: W_new = [11.8 38.2], MSE = 3047.75
# Iteration #0: W_new = [11.8 38.2], MSE = 3047.75
# Iteration #10: W_new = [12651.73553914 69617.0969639 ], MSE = 18310954068.05
# Iteration #20: W_new = [ 7732434.81888021 42641607.37852183], MSE = 9128819654907562.0
# Iteration #30: W_new = [1.06344502e+09 5.86454589e+09], MSE = 2.327920364266843e+20
# Iteration #40: W_new = [3.00127077e+10 1.65510116e+11], MSE = 2.545133529815939e+23
# Iteration #50: W_new = [1.55345341e+11 8.56677968e+11], MSE = 9.572295620500076e+24
# Iteration #60: W_new = [1.27742291e+11 7.04456313e+11], MSE = 9.351480126475981e+24
# Iteration #70: W_new = [1.38141953e+10 7.61806995e+10], MSE = 1.64085895282839e+23
# Iteration #80: W_new = [1.51674189e+08 8.36432543e+08], MSE = 3.12553353787446e+19
# Iteration #90: W_new = [116395.49987587 641638.79864391], MSE = 31317286806394.35
# Iteration #0: W_new = [11.8 38.2], MSE = 3047.75
# Iteration #10: W_new = [12651.73553914 69617.0969639 ], MSE = 18310954068.05
# Iteration #20: W_new = [ 7732434.81888021 42641607.37852183], MSE = 9128819654907562.0
# Iteration #30: W_new = [1.06344502e+09 5.86454589e+09], MSE = 2.327920364266843e+20
# Iteration #40: W_new = [3.00127077e+10 1.65510116e+11], MSE = 2.545133529815939e+23
# Iteration #50: W_new = [1.55345341e+11 8.56677968e+11], MSE = 9.572295620500076e+24
# Iteration #60: W_new = [1.27742291e+11 7.04456313e+11], MSE = 9.351480126475981e+24
# Iteration #70: W_new = [1.38141953e+10 7.61806995e+10], MSE = 1.64085895282839e+23
# Iteration #80: W_new = [1.51674189e+08 8.36432543e+08], MSE = 3.12553353787446e+19
# Iteration #90: W_new = [116395.49987587 641638.79864391], MSE = 31317286806394.35
# Iteration #100: W_new = [48.41966068 22.99883978], MSE = 53518.86
# Iteration #110: W_new = [44.97715771  3.82798364], MSE = 43.97
# Iteration #120: W_new = [44.99895221  3.82402341], MSE = 43.97
# Iteration #130: W_new = [45.01387838  3.82131678], MSE = 43.97
# Iteration #140: W_new = [45.02437076  3.81941415], MSE = 43.97
# Iteration #150: W_new = [45.03192327  3.81804462], MSE = 43.97
# Iteration #160: W_new = [45.03747771  3.81703741], MSE = 43.97
# Iteration #170: W_new = [45.04164307  3.81628208], MSE = 43.97
# Iteration #180: W_new = [45.04482243  3.81570555], MSE = 43.97
# Iteration #190: W_new = [45.04728844  3.81525838], MSE = 43.97
# Iteration #200: W_new = [45.0492292   3.81490646], MSE = 43.97
# Iteration #210: W_new = [45.05077689  3.81462581], MSE = 43.97
# Iteration #220: W_new = [45.052026   3.8143993], MSE = 43.97
# Iteration #230: W_new = [45.05304519  3.81421448], MSE = 43.97
# Iteration #240: W_new = [45.05388503  3.81406219], MSE = 43.97
# Iteration #0: W_new = [11.8 38.2], MSE = 3047.75
# Iteration #10: W_new = [12651.73553914 69617.0969639 ], MSE = 18310954068.05
# Iteration #20: W_new = [ 7732434.81888021 42641607.37852183], MSE = 9128819654907562.0
# Iteration #30: W_new = [1.06344502e+09 5.86454589e+09], MSE = 2.327920364266843e+20
# Iteration #40: W_new = [3.00127077e+10 1.65510116e+11], MSE = 2.545133529815939e+23
# Iteration #50: W_new = [1.55345341e+11 8.56677968e+11], MSE = 9.572295620500076e+24
# Iteration #60: W_new = [1.27742291e+11 7.04456313e+11], MSE = 9.351480126475981e+24
# Iteration #70: W_new = [1.38141953e+10 7.61806995e+10], MSE = 1.64085895282839e+23
# Iteration #80: W_new = [1.51674189e+08 8.36432543e+08], MSE = 3.12553353787446e+19
# Iteration #90: W_new = [116395.49987587 641638.79864391], MSE = 31317286806394.35
# Iteration #100: W_new = [48.41966068 22.99883978], MSE = 53518.86
# Iteration #110: W_new = [44.97715771  3.82798364], MSE = 43.97
# Iteration #120: W_new = [44.99895221  3.82402341], MSE = 43.97
# Iteration #130: W_new = [45.01387838  3.82131678], MSE = 43.97
# Iteration #140: W_new = [45.02437076  3.81941415], MSE = 43.97
# Iteration #150: W_new = [45.03192327  3.81804462], MSE = 43.97
# Iteration #160: W_new = [45.03747771  3.81703741], MSE = 43.97
# Iteration #170: W_new = [45.04164307  3.81628208], MSE = 43.97
# Iteration #180: W_new = [45.04482243  3.81570555], MSE = 43.97
# Iteration #190: W_new = [45.04728844  3.81525838], MSE = 43.97
# Iteration #200: W_new = [45.0492292   3.81490646], MSE = 43.97
# Iteration #210: W_new = [45.05077689  3.81462581], MSE = 43.97
# Iteration #220: W_new = [45.052026   3.8143993], MSE = 43.97
# Iteration #230: W_new = [45.05304519  3.81421448], MSE = 43.97
# Iteration #240: W_new = [45.05388503  3.81406219], MSE = 43.97
# Iteration #250: W_new = [45.05458332  3.81393557], MSE = 43.97
# Iteration #260: W_new = [45.05516867  3.81382942], MSE = 43.97
# Iteration #270: W_new = [45.055663    3.81373978], MSE = 43.97
# Iteration #280: W_new = [45.05608328  3.81366357], MSE = 43.97
# Iteration #290: W_new = [45.05644278  3.81359838], MSE = 43.97
# Iteration #300: W_new = [45.05675202  3.81354231], MSE = 43.97
# Iteration #310: W_new = [45.05701936  3.81349383], MSE = 43.97
# Iteration #320: W_new = [45.05725155  3.81345173], MSE = 43.97
# Iteration #330: W_new = [45.05745403  3.81341501], MSE = 43.97
# Iteration #340: W_new = [45.0576313   3.81338286], MSE = 43.97
# Iteration #350: W_new = [45.05778701  3.81335463], MSE = 43.97
# Iteration #360: W_new = [45.05792422  3.81332975], MSE = 43.97
# Iteration #370: W_new = [45.05804548  3.81330776], MSE = 43.97
# Iteration #380: W_new = [45.0581529   3.81328828], MSE = 43.97
# Iteration #390: W_new = [45.0582483   3.81327098], MSE = 43.97
# Iteration #400: W_new = [45.0583332   3.81325558], MSE = 43.97
# Iteration #410: W_new = [45.05840891  3.81324186], MSE = 43.97
# Iteration #420: W_new = [45.05847653  3.81322959], MSE = 43.97
# Iteration #430: W_new = [45.05853703  3.81321862], MSE = 43.97
# Iteration #440: W_new = [45.05859123  3.81320879], MSE = 43.97
# Iteration #450: W_new = [45.05863986  3.81319998], MSE = 43.97
# Iteration #460: W_new = [45.05868355  3.81319205], MSE = 43.97
# Iteration #470: W_new = [45.05872283  3.81318493], MSE = 43.97
# Iteration #480: W_new = [45.05875818  3.81317852], MSE = 43.97
# Iteration #490: W_new = [45.05879004  3.81317274], MSE = 43.97
# Iteration #0: W_new = [11.8 38.2], MSE = 3047.75
# Iteration #10: W_new = [12651.73553914 69617.0969639 ], MSE = 18310954068.05
# Iteration #20: W_new = [ 7732434.81888021 42641607.37852183], MSE = 9128819654907562.0
# Iteration #30: W_new = [1.06344502e+09 5.86454589e+09], MSE = 2.327920364266843e+20
# Iteration #40: W_new = [3.00127077e+10 1.65510116e+11], MSE = 2.545133529815939e+23
# Iteration #50: W_new = [1.55345341e+11 8.56677968e+11], MSE = 9.572295620500076e+24
# Iteration #60: W_new = [1.27742291e+11 7.04456313e+11], MSE = 9.351480126475981e+24
# Iteration #70: W_new = [1.38141953e+10 7.61806995e+10], MSE = 1.64085895282839e+23
# Iteration #80: W_new = [1.51674189e+08 8.36432543e+08], MSE = 3.12553353787446e+19
# Iteration #90: W_new = [116395.49987587 641638.79864391], MSE = 31317286806394.35
# Iteration #100: W_new = [48.41966068 22.99883978], MSE = 53518.86
# Iteration #110: W_new = [44.97715771  3.82798364], MSE = 43.97
# Iteration #120: W_new = [44.99895221  3.82402341], MSE = 43.97
# Iteration #130: W_new = [45.01387838  3.82131678], MSE = 43.97
# Iteration #140: W_new = [45.02437076  3.81941415], MSE = 43.97
# Iteration #150: W_new = [45.03192327  3.81804462], MSE = 43.97
# Iteration #160: W_new = [45.03747771  3.81703741], MSE = 43.97
# Iteration #170: W_new = [45.04164307  3.81628208], MSE = 43.97
# Iteration #180: W_new = [45.04482243  3.81570555], MSE = 43.97
# Iteration #190: W_new = [45.04728844  3.81525838], MSE = 43.97
# Iteration #200: W_new = [45.0492292   3.81490646], MSE = 43.97
# Iteration #210: W_new = [45.05077689  3.81462581], MSE = 43.97
# Iteration #220: W_new = [45.052026   3.8143993], MSE = 43.97
# Iteration #230: W_new = [45.05304519  3.81421448], MSE = 43.97
# Iteration #240: W_new = [45.05388503  3.81406219], MSE = 43.97
# Iteration #250: W_new = [45.05458332  3.81393557], MSE = 43.97
# Iteration #260: W_new = [45.05516867  3.81382942], MSE = 43.97
# Iteration #270: W_new = [45.055663    3.81373978], MSE = 43.97
# Iteration #280: W_new = [45.05608328  3.81366357], MSE = 43.97
# Iteration #290: W_new = [45.05644278  3.81359838], MSE = 43.97
# Iteration #300: W_new = [45.05675202  3.81354231], MSE = 43.97
# Iteration #310: W_new = [45.05701936  3.81349383], MSE = 43.97
# Iteration #320: W_new = [45.05725155  3.81345173], MSE = 43.97
# Iteration #330: W_new = [45.05745403  3.81341501], MSE = 43.97
# Iteration #340: W_new = [45.0576313   3.81338286], MSE = 43.97
# Iteration #350: W_new = [45.05778701  3.81335463], MSE = 43.97
# Iteration #360: W_new = [45.05792422  3.81332975], MSE = 43.97
# Iteration #370: W_new = [45.05804548  3.81330776], MSE = 43.97
# Iteration #380: W_new = [45.0581529   3.81328828], MSE = 43.97
# Iteration #390: W_new = [45.0582483   3.81327098], MSE = 43.97
# Iteration #400: W_new = [45.0583332   3.81325558], MSE = 43.97
# Iteration #410: W_new = [45.05840891  3.81324186], MSE = 43.97
# Iteration #420: W_new = [45.05847653  3.81322959], MSE = 43.97
# Iteration #430: W_new = [45.05853703  3.81321862], MSE = 43.97
# Iteration #440: W_new = [45.05859123  3.81320879], MSE = 43.97
# Iteration #450: W_new = [45.05863986  3.81319998], MSE = 43.97
# Iteration #460: W_new = [45.05868355  3.81319205], MSE = 43.97
# Iteration #470: W_new = [45.05872283  3.81318493], MSE = 43.97
# Iteration #480: W_new = [45.05875818  3.81317852], MSE = 43.97
# Iteration #490: W_new = [45.05879004  3.81317274], MSE = 43.97
# Iteration #500: W_new = [45.05881876  3.81316754], MSE = 43.97
# Iteration #510: W_new = [45.05884468  3.81316284], MSE = 43.97
# Iteration #520: W_new = [45.05886808  3.81315859], MSE = 43.97
# Iteration #530: W_new = [45.05888922  3.81315476], MSE = 43.97
# Iteration #540: W_new = [45.05890834  3.81315129], MSE = 43.97
# Iteration #550: W_new = [45.05892562  3.81314816], MSE = 43.97
# Iteration #560: W_new = [45.05894127  3.81314532], MSE = 43.97
# Iteration #570: W_new = [45.05895543  3.81314275], MSE = 43.97
# Iteration #580: W_new = [45.05896825  3.81314043], MSE = 43.97
# Iteration #590: W_new = [45.05897987  3.81313832], MSE = 43.97
# Iteration #600: W_new = [45.0589904   3.81313641], MSE = 43.97
# Iteration #610: W_new = [45.05899995  3.81313468], MSE = 43.97
# Iteration #620: W_new = [45.0590086   3.81313311], MSE = 43.97
# Iteration #630: W_new = [45.05901645  3.81313169], MSE = 43.97
# Iteration #640: W_new = [45.05902357  3.8131304 ], MSE = 43.97
# Iteration #650: W_new = [45.05903003  3.81312923], MSE = 43.97
# Iteration #660: W_new = [45.05903589  3.81312816], MSE = 43.97
# Iteration #670: W_new = [45.05904121  3.8131272 ], MSE = 43.97
# Iteration #680: W_new = [45.05904604  3.81312632], MSE = 43.97
# Iteration #690: W_new = [45.05905043  3.81312553], MSE = 43.97
# Iteration #700: W_new = [45.05905441  3.8131248 ], MSE = 43.97
# Iteration #710: W_new = [45.05905803  3.81312415], MSE = 43.97
# Iteration #720: W_new = [45.05906131  3.81312355], MSE = 43.97
# Iteration #730: W_new = [45.05906429  3.81312301], MSE = 43.97
# Iteration #740: W_new = [45.059067    3.81312252], MSE = 43.97
# Iteration #750: W_new = [45.05906946  3.81312208], MSE = 43.97
# Iteration #760: W_new = [45.0590717   3.81312167], MSE = 43.97
# Iteration #770: W_new = [45.05907373  3.8131213 ], MSE = 43.97
# Iteration #780: W_new = [45.05907557  3.81312097], MSE = 43.97
# Iteration #790: W_new = [45.05907725  3.81312066], MSE = 43.97
# Iteration #0: W_new = [11.8 38.2], MSE = 3047.75
# Iteration #10: W_new = [12651.73553914 69617.0969639 ], MSE = 18310954068.05
# Iteration #20: W_new = [ 7732434.81888021 42641607.37852183], MSE = 9128819654907562.0
# Iteration #30: W_new = [1.06344502e+09 5.86454589e+09], MSE = 2.327920364266843e+20
# Iteration #40: W_new = [3.00127077e+10 1.65510116e+11], MSE = 2.545133529815939e+23
# Iteration #50: W_new = [1.55345341e+11 8.56677968e+11], MSE = 9.572295620500076e+24
# Iteration #60: W_new = [1.27742291e+11 7.04456313e+11], MSE = 9.351480126475981e+24
# Iteration #70: W_new = [1.38141953e+10 7.61806995e+10], MSE = 1.64085895282839e+23
# Iteration #80: W_new = [1.51674189e+08 8.36432543e+08], MSE = 3.12553353787446e+19
# Iteration #90: W_new = [116395.49987587 641638.79864391], MSE = 31317286806394.35
# Iteration #100: W_new = [48.41966068 22.99883978], MSE = 53518.86
# Iteration #110: W_new = [44.97715771  3.82798364], MSE = 43.97
# Iteration #120: W_new = [44.99895221  3.82402341], MSE = 43.97
# Iteration #130: W_new = [45.01387838  3.82131678], MSE = 43.97
# Iteration #140: W_new = [45.02437076  3.81941415], MSE = 43.97
# Iteration #150: W_new = [45.03192327  3.81804462], MSE = 43.97
# Iteration #160: W_new = [45.03747771  3.81703741], MSE = 43.97
# Iteration #170: W_new = [45.04164307  3.81628208], MSE = 43.97
# Iteration #180: W_new = [45.04482243  3.81570555], MSE = 43.97
# Iteration #190: W_new = [45.04728844  3.81525838], MSE = 43.97
# Iteration #200: W_new = [45.0492292   3.81490646], MSE = 43.97
# Iteration #210: W_new = [45.05077689  3.81462581], MSE = 43.97
# Iteration #220: W_new = [45.052026   3.8143993], MSE = 43.97
# Iteration #230: W_new = [45.05304519  3.81421448], MSE = 43.97
# Iteration #240: W_new = [45.05388503  3.81406219], MSE = 43.97
# Iteration #250: W_new = [45.05458332  3.81393557], MSE = 43.97
# Iteration #260: W_new = [45.05516867  3.81382942], MSE = 43.97
# Iteration #270: W_new = [45.055663    3.81373978], MSE = 43.97
# Iteration #280: W_new = [45.05608328  3.81366357], MSE = 43.97
# Iteration #290: W_new = [45.05644278  3.81359838], MSE = 43.97
# Iteration #300: W_new = [45.05675202  3.81354231], MSE = 43.97
# Iteration #310: W_new = [45.05701936  3.81349383], MSE = 43.97
# Iteration #320: W_new = [45.05725155  3.81345173], MSE = 43.97
# Iteration #330: W_new = [45.05745403  3.81341501], MSE = 43.97
# Iteration #340: W_new = [45.0576313   3.81338286], MSE = 43.97
# Iteration #350: W_new = [45.05778701  3.81335463], MSE = 43.97
# Iteration #360: W_new = [45.05792422  3.81332975], MSE = 43.97
# Iteration #370: W_new = [45.05804548  3.81330776], MSE = 43.97
# Iteration #380: W_new = [45.0581529   3.81328828], MSE = 43.97
# Iteration #390: W_new = [45.0582483   3.81327098], MSE = 43.97
# Iteration #400: W_new = [45.0583332   3.81325558], MSE = 43.97
# Iteration #410: W_new = [45.05840891  3.81324186], MSE = 43.97
# Iteration #420: W_new = [45.05847653  3.81322959], MSE = 43.97
# Iteration #430: W_new = [45.05853703  3.81321862], MSE = 43.97
# Iteration #440: W_new = [45.05859123  3.81320879], MSE = 43.97
# Iteration #450: W_new = [45.05863986  3.81319998], MSE = 43.97
# Iteration #460: W_new = [45.05868355  3.81319205], MSE = 43.97
# Iteration #470: W_new = [45.05872283  3.81318493], MSE = 43.97
# Iteration #480: W_new = [45.05875818  3.81317852], MSE = 43.97
# Iteration #490: W_new = [45.05879004  3.81317274], MSE = 43.97
# Iteration #500: W_new = [45.05881876  3.81316754], MSE = 43.97
# Iteration #510: W_new = [45.05884468  3.81316284], MSE = 43.97
# Iteration #520: W_new = [45.05886808  3.81315859], MSE = 43.97
# Iteration #530: W_new = [45.05888922  3.81315476], MSE = 43.97
# Iteration #540: W_new = [45.05890834  3.81315129], MSE = 43.97
# Iteration #550: W_new = [45.05892562  3.81314816], MSE = 43.97
# Iteration #560: W_new = [45.05894127  3.81314532], MSE = 43.97
# Iteration #570: W_new = [45.05895543  3.81314275], MSE = 43.97
# Iteration #580: W_new = [45.05896825  3.81314043], MSE = 43.97
# Iteration #590: W_new = [45.05897987  3.81313832], MSE = 43.97
# Iteration #600: W_new = [45.0589904   3.81313641], MSE = 43.97
# Iteration #610: W_new = [45.05899995  3.81313468], MSE = 43.97
# Iteration #620: W_new = [45.0590086   3.81313311], MSE = 43.97
# Iteration #630: W_new = [45.05901645  3.81313169], MSE = 43.97
# Iteration #640: W_new = [45.05902357  3.8131304 ], MSE = 43.97
# Iteration #650: W_new = [45.05903003  3.81312923], MSE = 43.97
# Iteration #660: W_new = [45.05903589  3.81312816], MSE = 43.97
# Iteration #670: W_new = [45.05904121  3.8131272 ], MSE = 43.97
# Iteration #680: W_new = [45.05904604  3.81312632], MSE = 43.97
# Iteration #690: W_new = [45.05905043  3.81312553], MSE = 43.97
# Iteration #700: W_new = [45.05905441  3.8131248 ], MSE = 43.97
# Iteration #710: W_new = [45.05905803  3.81312415], MSE = 43.97
# Iteration #720: W_new = [45.05906131  3.81312355], MSE = 43.97
# Iteration #730: W_new = [45.05906429  3.81312301], MSE = 43.97
# Iteration #740: W_new = [45.059067    3.81312252], MSE = 43.97
# Iteration #750: W_new = [45.05906946  3.81312208], MSE = 43.97
# Iteration #760: W_new = [45.0590717   3.81312167], MSE = 43.97
# Iteration #770: W_new = [45.05907373  3.8131213 ], MSE = 43.97
# Iteration #780: W_new = [45.05907557  3.81312097], MSE = 43.97
# Iteration #790: W_new = [45.05907725  3.81312066], MSE = 43.97
# Iteration #800: W_new = [45.05907877  3.81312039], MSE = 43.97
# Iteration #810: W_new = [45.05908016  3.81312014], MSE = 43.97
# Iteration #820: W_new = [45.05908142  3.81311991], MSE = 43.97
# Iteration #830: W_new = [45.05908256  3.8131197 ], MSE = 43.97
# Iteration #840: W_new = [45.0590836   3.81311951], MSE = 43.97
# Iteration #850: W_new = [45.05908454  3.81311934], MSE = 43.97
# Iteration #860: W_new = [45.0590854   3.81311918], MSE = 43.97
# Iteration #870: W_new = [45.05908618  3.81311904], MSE = 43.97
# Iteration #880: W_new = [45.05908689  3.81311891], MSE = 43.97
# Iteration #890: W_new = [45.05908753  3.8131188 ], MSE = 43.97
# Iteration #900: W_new = [45.05908812  3.81311869], MSE = 43.97
# Iteration #910: W_new = [45.05908865  3.8131186 ], MSE = 43.97
# Iteration #920: W_new = [45.05908914  3.81311851], MSE = 43.97
# Iteration #930: W_new = [45.05908958  3.81311843], MSE = 43.97
# Iteration #940: W_new = [45.05908998  3.81311836], MSE = 43.97
# Iteration #950: W_new = [45.05909034  3.81311829], MSE = 43.97
# Iteration #960: W_new = [45.05909067  3.81311823], MSE = 43.97
# Iteration #970: W_new = [45.05909097  3.81311817], MSE = 43.97
# Iteration #980: W_new = [45.05909124  3.81311813], MSE = 43.97
# Iteration #990: W_new = [45.05909149  3.81311808], MSE = 43.97
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# Iteration #140: W_new = [43.73055537  4.05402762], MSE = 44.82
# Iteration #150: W_new = [43.8690146   4.02892018], MSE = 44.65
# Iteration #160: W_new = [43.9823022   4.00837722], MSE = 44.53
# Iteration #170: W_new = [44.0758912   3.99140629], MSE = 44.44
# Iteration #180: W_new = [44.15388587  3.97726316], MSE = 44.36
# Iteration #190: W_new = [44.21940291  3.96538266], MSE = 44.31
# Iteration #200: W_new = [44.27483692  3.95533056], MSE = 44.26
# Iteration #210: W_new = [44.32204803  3.94676955], MSE = 44.23
# Iteration #220: W_new = [44.36249605  3.93943492], MSE = 44.2
# Iteration #230: W_new = [44.39733771  3.93311693], MSE = 44.18
# Iteration #240: W_new = [44.42749793  3.92764784], MSE = 44.16
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# Iteration #140: W_new = [43.73055537  4.05402762], MSE = 44.82
# Iteration #150: W_new = [43.8690146   4.02892018], MSE = 44.65
# Iteration #160: W_new = [43.9823022   4.00837722], MSE = 44.53
# Iteration #170: W_new = [44.0758912   3.99140629], MSE = 44.44
# Iteration #180: W_new = [44.15388587  3.97726316], MSE = 44.36
# Iteration #190: W_new = [44.21940291  3.96538266], MSE = 44.31
# Iteration #200: W_new = [44.27483692  3.95533056], MSE = 44.26
# Iteration #210: W_new = [44.32204803  3.94676955], MSE = 44.23
# Iteration #220: W_new = [44.36249605  3.93943492], MSE = 44.2
# Iteration #230: W_new = [44.39733771  3.93311693], MSE = 44.18
# Iteration #240: W_new = [44.42749793  3.92764784], MSE = 44.16
# Iteration #250: W_new = [44.45372252  3.92289241], MSE = 44.14
# Iteration #260: W_new = [44.47661773  3.91874072], MSE = 44.13
# Iteration #270: W_new = [44.49668006  3.91510272], MSE = 44.12
# Iteration #280: W_new = [44.51431902  3.91190417], MSE = 44.11
# Iteration #290: W_new = [44.5298746  3.9090834], MSE = 44.1
# Iteration #300: W_new = [44.54363088  3.90658891], MSE = 44.1
# Iteration #310: W_new = [44.55582661  3.90437741], MSE = 44.09
# Iteration #320: W_new = [44.56666354  3.9024123 ], MSE = 44.09
# Iteration #330: W_new = [44.57631309  3.9006625 ], MSE = 44.08
# Iteration #340: W_new = [44.5849216   3.89910148], MSE = 44.08
# Iteration #350: W_new = [44.59261455  3.89770648], MSE = 44.07
# Iteration #360: W_new = [44.59950005  3.8964579 ], MSE = 44.07
# Iteration #370: W_new = [44.60567159  3.89533879], MSE = 44.07
# Iteration #380: W_new = [44.61121033  3.89433442], MSE = 44.06
# Iteration #390: W_new = [44.61618698  3.89343199], MSE = 44.06
# Iteration #400: W_new = [44.62066334  3.89262027], MSE = 44.06
# Iteration #410: W_new = [44.62469361  3.89188944], MSE = 44.06
# Iteration #420: W_new = [44.62832542  3.89123087], MSE = 44.06
# Iteration #430: W_new = [44.6316008   3.89063693], MSE = 44.06
# Iteration #440: W_new = [44.63455687  3.89010089], MSE = 44.06
# Iteration #450: W_new = [44.63722652  3.88961679], MSE = 44.05
# Iteration #460: W_new = [44.63963895  3.88917933], MSE = 44.05
# Iteration #470: W_new = [44.64182013  3.88878381], MSE = 44.05
# Iteration #480: W_new = [44.64379322  3.88842602], MSE = 44.05
# Iteration #490: W_new = [44.64557886  3.88810222], MSE = 44.05
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# Iteration #140: W_new = [43.73055537  4.05402762], MSE = 44.82
# Iteration #150: W_new = [43.8690146   4.02892018], MSE = 44.65
# Iteration #160: W_new = [43.9823022   4.00837722], MSE = 44.53
# Iteration #170: W_new = [44.0758912   3.99140629], MSE = 44.44
# Iteration #180: W_new = [44.15388587  3.97726316], MSE = 44.36
# Iteration #190: W_new = [44.21940291  3.96538266], MSE = 44.31
# Iteration #200: W_new = [44.27483692  3.95533056], MSE = 44.26
# Iteration #210: W_new = [44.32204803  3.94676955], MSE = 44.23
# Iteration #220: W_new = [44.36249605  3.93943492], MSE = 44.2
# Iteration #230: W_new = [44.39733771  3.93311693], MSE = 44.18
# Iteration #240: W_new = [44.42749793  3.92764784], MSE = 44.16
# Iteration #250: W_new = [44.45372252  3.92289241], MSE = 44.14
# Iteration #260: W_new = [44.47661773  3.91874072], MSE = 44.13
# Iteration #270: W_new = [44.49668006  3.91510272], MSE = 44.12
# Iteration #280: W_new = [44.51431902  3.91190417], MSE = 44.11
# Iteration #290: W_new = [44.5298746  3.9090834], MSE = 44.1
# Iteration #300: W_new = [44.54363088  3.90658891], MSE = 44.1
# Iteration #310: W_new = [44.55582661  3.90437741], MSE = 44.09
# Iteration #320: W_new = [44.56666354  3.9024123 ], MSE = 44.09
# Iteration #330: W_new = [44.57631309  3.9006625 ], MSE = 44.08
# Iteration #340: W_new = [44.5849216   3.89910148], MSE = 44.08
# Iteration #350: W_new = [44.59261455  3.89770648], MSE = 44.07
# Iteration #360: W_new = [44.59950005  3.8964579 ], MSE = 44.07
# Iteration #370: W_new = [44.60567159  3.89533879], MSE = 44.07
# Iteration #380: W_new = [44.61121033  3.89433442], MSE = 44.06
# Iteration #390: W_new = [44.61618698  3.89343199], MSE = 44.06
# Iteration #400: W_new = [44.62066334  3.89262027], MSE = 44.06
# Iteration #410: W_new = [44.62469361  3.89188944], MSE = 44.06
# Iteration #420: W_new = [44.62832542  3.89123087], MSE = 44.06
# Iteration #430: W_new = [44.6316008   3.89063693], MSE = 44.06
# Iteration #440: W_new = [44.63455687  3.89010089], MSE = 44.06
# Iteration #450: W_new = [44.63722652  3.88961679], MSE = 44.05
# Iteration #460: W_new = [44.63963895  3.88917933], MSE = 44.05
# Iteration #470: W_new = [44.64182013  3.88878381], MSE = 44.05
# Iteration #480: W_new = [44.64379322  3.88842602], MSE = 44.05
# Iteration #490: W_new = [44.64557886  3.88810222], MSE = 44.05
# Iteration #500: W_new = [44.64719553  3.88780906], MSE = 44.05
# Iteration #510: W_new = [44.64865977  3.88754355], MSE = 44.05
# Iteration #520: W_new = [44.64998639  3.88730298], MSE = 44.05
# Iteration #530: W_new = [44.6511887   3.88708496], MSE = 44.05
# Iteration #540: W_new = [44.65227866  3.88688732], MSE = 44.05
# Iteration #550: W_new = [44.653267    3.88670809], MSE = 44.05
# Iteration #560: W_new = [44.65416343  3.88654554], MSE = 44.05
# Iteration #570: W_new = [44.65497665  3.88639808], MSE = 44.05
# Iteration #580: W_new = [44.65571452  3.88626427], MSE = 44.05
# Iteration #590: W_new = [44.65638416  3.88614285], MSE = 44.05
# Iteration #600: W_new = [44.65699195  3.88603263], MSE = 44.05
# Iteration #610: W_new = [44.6575437   3.88593258], MSE = 44.05
# Iteration #620: W_new = [44.65804463  3.88584174], MSE = 44.05
# Iteration #630: W_new = [44.65849949  3.88575926], MSE = 44.05
# Iteration #640: W_new = [44.65891255  3.88568436], MSE = 44.05
# Iteration #650: W_new = [44.65928769  3.88561634], MSE = 44.05
# Iteration #660: W_new = [44.65962842  3.88555455], MSE = 44.05
# Iteration #670: W_new = [44.65993792  3.88549843], MSE = 44.05
# Iteration #680: W_new = [44.66021908  3.88544744], MSE = 44.04
# Iteration #690: W_new = [44.66047451  3.88540112], MSE = 44.04
# Iteration #700: W_new = [44.66070658  3.88535904], MSE = 44.04
# Iteration #710: W_new = [44.66091743  3.88532081], MSE = 44.04
# Iteration #720: W_new = [44.66110902  3.88528606], MSE = 44.04
# Iteration #730: W_new = [44.66128311  3.8852545 ], MSE = 44.04
# Iteration #740: W_new = [44.66144131  3.88522581], MSE = 44.04
# Iteration #750: W_new = [44.66158508  3.88519974], MSE = 44.04
# Iteration #760: W_new = [44.66171573  3.88517605], MSE = 44.04
# Iteration #770: W_new = [44.66183446  3.88515452], MSE = 44.04
# Iteration #780: W_new = [44.66194237  3.88513495], MSE = 44.04
# Iteration #790: W_new = [44.66204045  3.88511717], MSE = 44.04
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# Iteration #140: W_new = [43.73055537  4.05402762], MSE = 44.82
# Iteration #150: W_new = [43.8690146   4.02892018], MSE = 44.65
# Iteration #160: W_new = [43.9823022   4.00837722], MSE = 44.53
# Iteration #170: W_new = [44.0758912   3.99140629], MSE = 44.44
# Iteration #180: W_new = [44.15388587  3.97726316], MSE = 44.36
# Iteration #190: W_new = [44.21940291  3.96538266], MSE = 44.31
# Iteration #200: W_new = [44.27483692  3.95533056], MSE = 44.26
# Iteration #210: W_new = [44.32204803  3.94676955], MSE = 44.23
# Iteration #220: W_new = [44.36249605  3.93943492], MSE = 44.2
# Iteration #230: W_new = [44.39733771  3.93311693], MSE = 44.18
# Iteration #240: W_new = [44.42749793  3.92764784], MSE = 44.16
# Iteration #250: W_new = [44.45372252  3.92289241], MSE = 44.14
# Iteration #260: W_new = [44.47661773  3.91874072], MSE = 44.13
# Iteration #270: W_new = [44.49668006  3.91510272], MSE = 44.12
# Iteration #280: W_new = [44.51431902  3.91190417], MSE = 44.11
# Iteration #290: W_new = [44.5298746  3.9090834], MSE = 44.1
# Iteration #300: W_new = [44.54363088  3.90658891], MSE = 44.1
# Iteration #310: W_new = [44.55582661  3.90437741], MSE = 44.09
# Iteration #320: W_new = [44.56666354  3.9024123 ], MSE = 44.09
# Iteration #330: W_new = [44.57631309  3.9006625 ], MSE = 44.08
# Iteration #340: W_new = [44.5849216   3.89910148], MSE = 44.08
# Iteration #350: W_new = [44.59261455  3.89770648], MSE = 44.07
# Iteration #360: W_new = [44.59950005  3.8964579 ], MSE = 44.07
# Iteration #370: W_new = [44.60567159  3.89533879], MSE = 44.07
# Iteration #380: W_new = [44.61121033  3.89433442], MSE = 44.06
# Iteration #390: W_new = [44.61618698  3.89343199], MSE = 44.06
# Iteration #400: W_new = [44.62066334  3.89262027], MSE = 44.06
# Iteration #410: W_new = [44.62469361  3.89188944], MSE = 44.06
# Iteration #420: W_new = [44.62832542  3.89123087], MSE = 44.06
# Iteration #430: W_new = [44.6316008   3.89063693], MSE = 44.06
# Iteration #440: W_new = [44.63455687  3.89010089], MSE = 44.06
# Iteration #450: W_new = [44.63722652  3.88961679], MSE = 44.05
# Iteration #460: W_new = [44.63963895  3.88917933], MSE = 44.05
# Iteration #470: W_new = [44.64182013  3.88878381], MSE = 44.05
# Iteration #480: W_new = [44.64379322  3.88842602], MSE = 44.05
# Iteration #490: W_new = [44.64557886  3.88810222], MSE = 44.05
# Iteration #500: W_new = [44.64719553  3.88780906], MSE = 44.05
# Iteration #510: W_new = [44.64865977  3.88754355], MSE = 44.05
# Iteration #520: W_new = [44.64998639  3.88730298], MSE = 44.05
# Iteration #530: W_new = [44.6511887   3.88708496], MSE = 44.05
# Iteration #540: W_new = [44.65227866  3.88688732], MSE = 44.05
# Iteration #550: W_new = [44.653267    3.88670809], MSE = 44.05
# Iteration #560: W_new = [44.65416343  3.88654554], MSE = 44.05
# Iteration #570: W_new = [44.65497665  3.88639808], MSE = 44.05
# Iteration #580: W_new = [44.65571452  3.88626427], MSE = 44.05
# Iteration #590: W_new = [44.65638416  3.88614285], MSE = 44.05
# Iteration #600: W_new = [44.65699195  3.88603263], MSE = 44.05
# Iteration #610: W_new = [44.6575437   3.88593258], MSE = 44.05
# Iteration #620: W_new = [44.65804463  3.88584174], MSE = 44.05
# Iteration #630: W_new = [44.65849949  3.88575926], MSE = 44.05
# Iteration #640: W_new = [44.65891255  3.88568436], MSE = 44.05
# Iteration #650: W_new = [44.65928769  3.88561634], MSE = 44.05
# Iteration #660: W_new = [44.65962842  3.88555455], MSE = 44.05
# Iteration #670: W_new = [44.65993792  3.88549843], MSE = 44.05
# Iteration #680: W_new = [44.66021908  3.88544744], MSE = 44.04
# Iteration #690: W_new = [44.66047451  3.88540112], MSE = 44.04
# Iteration #700: W_new = [44.66070658  3.88535904], MSE = 44.04
# Iteration #710: W_new = [44.66091743  3.88532081], MSE = 44.04
# Iteration #720: W_new = [44.66110902  3.88528606], MSE = 44.04
# Iteration #730: W_new = [44.66128311  3.8852545 ], MSE = 44.04
# Iteration #740: W_new = [44.66144131  3.88522581], MSE = 44.04
# Iteration #750: W_new = [44.66158508  3.88519974], MSE = 44.04
# Iteration #760: W_new = [44.66171573  3.88517605], MSE = 44.04
# Iteration #770: W_new = [44.66183446  3.88515452], MSE = 44.04
# Iteration #780: W_new = [44.66194237  3.88513495], MSE = 44.04
# Iteration #790: W_new = [44.66204045  3.88511717], MSE = 44.04
# Iteration #800: W_new = [44.66212958  3.885101  ], MSE = 44.04
# Iteration #810: W_new = [44.6622106   3.88508631], MSE = 44.04
# Iteration #820: W_new = [44.66228424  3.88507296], MSE = 44.04
# Iteration #830: W_new = [44.66235117  3.88506082], MSE = 44.04
# Iteration #840: W_new = [44.66241201  3.88504979], MSE = 44.04
# Iteration #850: W_new = [44.6624673   3.88503976], MSE = 44.04
# Iteration #860: W_new = [44.66251757  3.88503065], MSE = 44.04
# Iteration #870: W_new = [44.66256326  3.88502236], MSE = 44.04
# Iteration #880: W_new = [44.66260479  3.88501483], MSE = 44.04
# Iteration #890: W_new = [44.66264254  3.88500799], MSE = 44.04
# Iteration #900: W_new = [44.66267686  3.88500176], MSE = 44.04
# Iteration #910: W_new = [44.66270805  3.88499611], MSE = 44.04
# Iteration #920: W_new = [44.66273641  3.88499096], MSE = 44.04
# Iteration #930: W_new = [44.66276219  3.88498629], MSE = 44.04
# Iteration #940: W_new = [44.66278562  3.88498204], MSE = 44.04
# Iteration #950: W_new = [44.66280692  3.88497818], MSE = 44.04
# Iteration #960: W_new = [44.66282628  3.88497467], MSE = 44.04
# Iteration #970: W_new = [44.66284389  3.88497147], MSE = 44.04
# Iteration #980: W_new = [44.66285989  3.88496857], MSE = 44.04
# Iteration #990: W_new = [44.66287443  3.88496594], MSE = 44.04
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65
# Iteration #100: W_new = [21.29557245  8.12226587], MSE = 311.9
# Iteration #110: W_new = [22.044442    7.98646992], MSE = 295.12
# Iteration #120: W_new = [22.7046421   7.86675281], MSE = 280.78
# Iteration #130: W_new = [23.2883015   7.76091518], MSE = 268.46
# Iteration #140: W_new = [23.80560705  7.66710979], MSE = 257.81
# Iteration #150: W_new = [24.26516249  7.5837765 ], MSE = 248.58
# Iteration #160: W_new = [24.67427278  7.50959066], MSE = 240.53
# Iteration #170: W_new = [25.03917079  7.44342203], MSE = 233.49
# Iteration #180: W_new = [25.36519943  7.38430176], MSE = 227.31
# Iteration #190: W_new = [25.65695861  7.33139573], MSE = 221.86
# Iteration #200: W_new = [25.91842478  7.28398287], MSE = 217.05
# Iteration #210: W_new = [26.15304857  7.24143747], MSE = 212.8
# Iteration #220: W_new = [26.36383499  7.2032146 ], MSE = 209.02
# Iteration #230: W_new = [26.55340974  7.16883814], MSE = 205.65
# Iteration #240: W_new = [26.72407419  7.13789077], MSE = 202.66
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65
# Iteration #100: W_new = [21.29557245  8.12226587], MSE = 311.9
# Iteration #110: W_new = [22.044442    7.98646992], MSE = 295.12
# Iteration #120: W_new = [22.7046421   7.86675281], MSE = 280.78
# Iteration #130: W_new = [23.2883015   7.76091518], MSE = 268.46
# Iteration #140: W_new = [23.80560705  7.66710979], MSE = 257.81
# Iteration #150: W_new = [24.26516249  7.5837765 ], MSE = 248.58
# Iteration #160: W_new = [24.67427278  7.50959066], MSE = 240.53
# Iteration #170: W_new = [25.03917079  7.44342203], MSE = 233.49
# Iteration #180: W_new = [25.36519943  7.38430176], MSE = 227.31
# Iteration #190: W_new = [25.65695861  7.33139573], MSE = 221.86
# Iteration #200: W_new = [25.91842478  7.28398287], MSE = 217.05
# Iteration #210: W_new = [26.15304857  7.24143747], MSE = 212.8
# Iteration #220: W_new = [26.36383499  7.2032146 ], MSE = 209.02
# Iteration #230: W_new = [26.55340974  7.16883814], MSE = 205.65
# Iteration #240: W_new = [26.72407419  7.13789077], MSE = 202.66
# Iteration #250: W_new = [26.87785132  7.11000566], MSE = 199.98
# Iteration #260: W_new = [27.01652415  7.08485948], MSE = 197.59
# Iteration #270: W_new = [27.14166815  7.06216655], MSE = 195.44
# Iteration #280: W_new = [27.25467861  7.04167384], MSE = 193.52
# Iteration #290: W_new = [27.35679393  7.02315681], MSE = 191.79
# Iteration #300: W_new = [27.44911541  7.00641573], MSE = 190.24
# Iteration #310: W_new = [27.53262425  6.99127269], MSE = 188.84
# Iteration #320: W_new = [27.60819612  6.97756889], MSE = 187.58
# Iteration #330: W_new = [27.67661373  6.96516242], MSE = 186.45
# Iteration #340: W_new = [27.73857771  6.9539262 ], MSE = 185.42
# Iteration #350: W_new = [27.79471602  6.94374639], MSE = 184.5
# Iteration #360: W_new = [27.84559223  6.93452077], MSE = 183.66
# Iteration #370: W_new = [27.89171262  6.92615755], MSE = 182.91
# Iteration #380: W_new = [27.93353252  6.91857415], MSE = 182.23
# Iteration #390: W_new = [27.9714618   6.91169626], MSE = 181.61
# Iteration #400: W_new = [28.00586973  6.90545692], MSE = 181.05
# Iteration #410: W_new = [28.03708926  6.89979574], MSE = 180.54
# Iteration #420: W_new = [28.06542083  6.89465824], MSE = 180.08
# Iteration #430: W_new = [28.0911357   6.88999525], MSE = 179.67
# Iteration #440: W_new = [28.11447893  6.88576231], MSE = 179.29
# Iteration #450: W_new = [28.13567205  6.88191927], MSE = 178.95
# Iteration #460: W_new = [28.15491542  6.87842978], MSE = 178.64
# Iteration #470: W_new = [28.17239031  6.87526098], MSE = 178.36
# Iteration #480: W_new = [28.18826083  6.8723831 ], MSE = 178.1
# Iteration #490: W_new = [28.20267557  6.86976921], MSE = 177.87
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65
# Iteration #100: W_new = [21.29557245  8.12226587], MSE = 311.9
# Iteration #110: W_new = [22.044442    7.98646992], MSE = 295.12
# Iteration #120: W_new = [22.7046421   7.86675281], MSE = 280.78
# Iteration #130: W_new = [23.2883015   7.76091518], MSE = 268.46
# Iteration #140: W_new = [23.80560705  7.66710979], MSE = 257.81
# Iteration #150: W_new = [24.26516249  7.5837765 ], MSE = 248.58
# Iteration #160: W_new = [24.67427278  7.50959066], MSE = 240.53
# Iteration #170: W_new = [25.03917079  7.44342203], MSE = 233.49
# Iteration #180: W_new = [25.36519943  7.38430176], MSE = 227.31
# Iteration #190: W_new = [25.65695861  7.33139573], MSE = 221.86
# Iteration #200: W_new = [25.91842478  7.28398287], MSE = 217.05
# Iteration #210: W_new = [26.15304857  7.24143747], MSE = 212.8
# Iteration #220: W_new = [26.36383499  7.2032146 ], MSE = 209.02
# Iteration #230: W_new = [26.55340974  7.16883814], MSE = 205.65
# Iteration #240: W_new = [26.72407419  7.13789077], MSE = 202.66
# Iteration #250: W_new = [26.87785132  7.11000566], MSE = 199.98
# Iteration #260: W_new = [27.01652415  7.08485948], MSE = 197.59
# Iteration #270: W_new = [27.14166815  7.06216655], MSE = 195.44
# Iteration #280: W_new = [27.25467861  7.04167384], MSE = 193.52
# Iteration #290: W_new = [27.35679393  7.02315681], MSE = 191.79
# Iteration #300: W_new = [27.44911541  7.00641573], MSE = 190.24
# Iteration #310: W_new = [27.53262425  6.99127269], MSE = 188.84
# Iteration #320: W_new = [27.60819612  6.97756889], MSE = 187.58
# Iteration #330: W_new = [27.67661373  6.96516242], MSE = 186.45
# Iteration #340: W_new = [27.73857771  6.9539262 ], MSE = 185.42
# Iteration #350: W_new = [27.79471602  6.94374639], MSE = 184.5
# Iteration #360: W_new = [27.84559223  6.93452077], MSE = 183.66
# Iteration #370: W_new = [27.89171262  6.92615755], MSE = 182.91
# Iteration #380: W_new = [27.93353252  6.91857415], MSE = 182.23
# Iteration #390: W_new = [27.9714618   6.91169626], MSE = 181.61
# Iteration #400: W_new = [28.00586973  6.90545692], MSE = 181.05
# Iteration #410: W_new = [28.03708926  6.89979574], MSE = 180.54
# Iteration #420: W_new = [28.06542083  6.89465824], MSE = 180.08
# Iteration #430: W_new = [28.0911357   6.88999525], MSE = 179.67
# Iteration #440: W_new = [28.11447893  6.88576231], MSE = 179.29
# Iteration #450: W_new = [28.13567205  6.88191927], MSE = 178.95
# Iteration #460: W_new = [28.15491542  6.87842978], MSE = 178.64
# Iteration #470: W_new = [28.17239031  6.87526098], MSE = 178.36
# Iteration #480: W_new = [28.18826083  6.8723831 ], MSE = 178.1
# Iteration #490: W_new = [28.20267557  6.86976921], MSE = 177.87
# Iteration #500: W_new = [28.21576915  6.86739489], MSE = 177.66
# Iteration #510: W_new = [28.22766353  6.86523803], MSE = 177.47
# Iteration #520: W_new = [28.23846929  6.86327857], MSE = 177.3
# Iteration #530: W_new = [28.24828665  6.86149835], MSE = 177.14
# Iteration #540: W_new = [28.25720653  6.85988086], MSE = 177.0
# Iteration #550: W_new = [28.26531139  6.85841117], MSE = 176.87
# Iteration #560: W_new = [28.27267604  6.85707571], MSE = 176.75
# Iteration #570: W_new = [28.27936835  6.85586216], MSE = 176.64
# Iteration #580: W_new = [28.28544995  6.85475935], MSE = 176.55
# Iteration #590: W_new = [28.29097675  6.85375715], MSE = 176.46
# Iteration #600: W_new = [28.29599953  6.85284635], MSE = 176.38
# Iteration #610: W_new = [28.30056439  6.85201858], MSE = 176.31
# Iteration #620: W_new = [28.30471317  6.85126627], MSE = 176.24
# Iteration #630: W_new = [28.30848389  6.8505825 ], MSE = 176.18
# Iteration #640: W_new = [28.31191108  6.84996104], MSE = 176.13
# Iteration #650: W_new = [28.3150261   6.84939618], MSE = 176.08
# Iteration #660: W_new = [28.31785743  6.84888276], MSE = 176.03
# Iteration #670: W_new = [28.32043095  6.84841609], MSE = 175.99
# Iteration #680: W_new = [28.32277016  6.84799191], MSE = 175.95
# Iteration #690: W_new = [28.32489644  6.84760634], MSE = 175.92
# Iteration #700: W_new = [28.32682918  6.84725587], MSE = 175.89
# Iteration #710: W_new = [28.32858603  6.84693729], MSE = 175.86
# Iteration #720: W_new = [28.330183    6.84664771], MSE = 175.83
# Iteration #730: W_new = [28.33163466  6.84638447], MSE = 175.81
# Iteration #740: W_new = [28.33295423  6.84614518], MSE = 175.79
# Iteration #750: W_new = [28.33415376  6.84592767], MSE = 175.77
# Iteration #760: W_new = [28.33524417  6.84572994], MSE = 175.75
# Iteration #770: W_new = [28.33623538  6.8455502 ], MSE = 175.74
# Iteration #780: W_new = [28.33713643  6.84538681], MSE = 175.72
# Iteration #790: W_new = [28.33795553  6.84523828], MSE = 175.71
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65
# Iteration #100: W_new = [21.29557245  8.12226587], MSE = 311.9
# Iteration #110: W_new = [22.044442    7.98646992], MSE = 295.12
# Iteration #120: W_new = [22.7046421   7.86675281], MSE = 280.78
# Iteration #130: W_new = [23.2883015   7.76091518], MSE = 268.46
# Iteration #140: W_new = [23.80560705  7.66710979], MSE = 257.81
# Iteration #150: W_new = [24.26516249  7.5837765 ], MSE = 248.58
# Iteration #160: W_new = [24.67427278  7.50959066], MSE = 240.53
# Iteration #170: W_new = [25.03917079  7.44342203], MSE = 233.49
# Iteration #180: W_new = [25.36519943  7.38430176], MSE = 227.31
# Iteration #190: W_new = [25.65695861  7.33139573], MSE = 221.86
# Iteration #200: W_new = [25.91842478  7.28398287], MSE = 217.05
# Iteration #210: W_new = [26.15304857  7.24143747], MSE = 212.8
# Iteration #220: W_new = [26.36383499  7.2032146 ], MSE = 209.02
# Iteration #230: W_new = [26.55340974  7.16883814], MSE = 205.65
# Iteration #240: W_new = [26.72407419  7.13789077], MSE = 202.66
# Iteration #250: W_new = [26.87785132  7.11000566], MSE = 199.98
# Iteration #260: W_new = [27.01652415  7.08485948], MSE = 197.59
# Iteration #270: W_new = [27.14166815  7.06216655], MSE = 195.44
# Iteration #280: W_new = [27.25467861  7.04167384], MSE = 193.52
# Iteration #290: W_new = [27.35679393  7.02315681], MSE = 191.79
# Iteration #300: W_new = [27.44911541  7.00641573], MSE = 190.24
# Iteration #310: W_new = [27.53262425  6.99127269], MSE = 188.84
# Iteration #320: W_new = [27.60819612  6.97756889], MSE = 187.58
# Iteration #330: W_new = [27.67661373  6.96516242], MSE = 186.45
# Iteration #340: W_new = [27.73857771  6.9539262 ], MSE = 185.42
# Iteration #350: W_new = [27.79471602  6.94374639], MSE = 184.5
# Iteration #360: W_new = [27.84559223  6.93452077], MSE = 183.66
# Iteration #370: W_new = [27.89171262  6.92615755], MSE = 182.91
# Iteration #380: W_new = [27.93353252  6.91857415], MSE = 182.23
# Iteration #390: W_new = [27.9714618   6.91169626], MSE = 181.61
# Iteration #400: W_new = [28.00586973  6.90545692], MSE = 181.05
# Iteration #410: W_new = [28.03708926  6.89979574], MSE = 180.54
# Iteration #420: W_new = [28.06542083  6.89465824], MSE = 180.08
# Iteration #430: W_new = [28.0911357   6.88999525], MSE = 179.67
# Iteration #440: W_new = [28.11447893  6.88576231], MSE = 179.29
# Iteration #450: W_new = [28.13567205  6.88191927], MSE = 178.95
# Iteration #460: W_new = [28.15491542  6.87842978], MSE = 178.64
# Iteration #470: W_new = [28.17239031  6.87526098], MSE = 178.36
# Iteration #480: W_new = [28.18826083  6.8723831 ], MSE = 178.1
# Iteration #490: W_new = [28.20267557  6.86976921], MSE = 177.87
# Iteration #500: W_new = [28.21576915  6.86739489], MSE = 177.66
# ...
# Iteration #10: W_new = [1.10784583 0.87425489], MSE = 2910.74
# Iteration #20: W_new = [1.19433808 1.17081028], MSE = 2793.57
# Iteration #30: W_new = [1.27157753 1.43285993], MSE = 2692.81
# Iteration #40: W_new = [1.34067642 1.66501505], MSE = 2605.72
# Iteration #50: W_new = [1.40259086 1.87116766], MSE = 2530.09
# Iteration #60: W_new = [1.45814668 2.05462009], MSE = 2464.14
# Iteration #70: W_new = [1.50806047 2.21818819], MSE = 2406.41
# Iteration #80: W_new = [1.55295649 2.36428416], MSE = 2355.7
# Iteration #90: W_new = [1.59338065 2.49498341], MSE = 2311.02
# Iteration #100: W_new = [1.629812   2.61207894], MSE = 2271.54
# Iteration #110: W_new = [1.66267221 2.71712571], MSE = 2236.56
# Iteration #120: W_new = [1.69233352 2.81147704], MSE = 2205.5
# Iteration #130: W_new = [1.7191254  2.89631477], MSE = 2177.86
# Iteration #140: W_new = [1.74334016 2.9726742 ], MSE = 2153.21
# Iteration #150: W_new = [1.76523771 3.04146487], MSE = 2131.19
# Iteration #160: W_new = [1.78504962 3.10348806], MSE = 2111.49
# Iteration #170: W_new = [1.80298257 3.15945145], MSE = 2093.84
# Iteration #180: W_new = [1.81922132 3.2099815 ], MSE = 2078.01
# Iteration #190: W_new = [1.83393132 3.25563396], MSE = 2063.78
# Iteration #200: W_new = [1.8472609 3.2969029], MSE = 2050.99
# Iteration #210: W_new = [1.85934324 3.33422833], MSE = 2039.48
# Iteration #220: W_new = [1.87029801 3.3680028 ], MSE = 2029.11
# Iteration #230: W_new = [1.88023288 3.39857706], MSE = 2019.76
# Iteration #240: W_new = [1.88924481 3.42626499], MSE = 2011.32
# Iteration #0: W_new = [1.0108 0.5377], MSE = 3047.75
# Iteration #10: W_new = [1.10784583 0.87425489], MSE = 2910.74
# Iteration #20: W_new = [1.19433808 1.17081028], MSE = 2793.57
# Iteration #30: W_new = [1.27157753 1.43285993], MSE = 2692.81
# Iteration #40: W_new = [1.34067642 1.66501505], MSE = 2605.72
# Iteration #50: W_new = [1.40259086 1.87116766], MSE = 2530.09
# Iteration #60: W_new = [1.45814668 2.05462009], MSE = 2464.14
# Iteration #70: W_new = [1.50806047 2.21818819], MSE = 2406.41
# Iteration #80: W_new = [1.55295649 2.36428416], MSE = 2355.7
# Iteration #90: W_new = [1.59338065 2.49498341], MSE = 2311.02
# Iteration #100: W_new = [1.629812   2.61207894], MSE = 2271.54
# Iteration #110: W_new = [1.66267221 2.71712571], MSE = 2236.56
# Iteration #120: W_new = [1.69233352 2.81147704], MSE = 2205.5
# Iteration #130: W_new = [1.7191254  2.89631477], MSE = 2177.86
# Iteration #140: W_new = [1.74334016 2.9726742 ], MSE = 2153.21
# Iteration #150: W_new = [1.76523771 3.04146487], MSE = 2131.19
# Iteration #160: W_new = [1.78504962 3.10348806], MSE = 2111.49
# Iteration #170: W_new = [1.80298257 3.15945145], MSE = 2093.84
# Iteration #180: W_new = [1.81922132 3.2099815 ], MSE = 2078.01
# Iteration #190: W_new = [1.83393132 3.25563396], MSE = 2063.78
# Iteration #200: W_new = [1.8472609 3.2969029], MSE = 2050.99
# Iteration #210: W_new = [1.85934324 3.33422833], MSE = 2039.48
# Iteration #220: W_new = [1.87029801 3.3680028 ], MSE = 2029.11
# Iteration #230: W_new = [1.88023288 3.39857706], MSE = 2019.76
# Iteration #240: W_new = [1.88924481 3.42626499], MSE = 2011.32
# Iteration #250: W_new = [1.8974212  3.45134785], MSE = 2003.7
# Iteration #260: W_new = [1.90484088 3.47407798], MSE = 1996.81
# Iteration #270: W_new = [1.91157499 3.49468201], MSE = 1990.59
# Iteration #280: W_new = [1.9176878  3.51336372], MSE = 1984.96
# Iteration #290: W_new = [1.92323739 3.53030652], MSE = 1979.86
# Iteration #300: W_new = [1.92827628 3.5456756 ], MSE = 1975.25
# Iteration #310: W_new = [1.93285198 3.5596199 ], MSE = 1971.07
# Iteration #320: W_new = [1.9370075  3.57227376], MSE = 1967.29
# Iteration #330: W_new = [1.94078177 3.5837585 ], MSE = 1963.86
# Iteration #340: W_new = [1.94421005 3.59418366], MSE = 1960.75
# Iteration #350: W_new = [1.9473243 3.6036483], MSE = 1957.94
# Iteration #360: W_new = [1.95015349 3.61224195], MSE = 1955.38
# Iteration #370: W_new = [1.95272386 3.62004565], MSE = 1953.06
# Iteration #380: W_new = [1.95505923 3.62713272], MSE = 1950.96
# Iteration #390: W_new = [1.9571812  3.63356957], MSE = 1949.05
# Iteration #400: W_new = [1.95910935 3.63941635], MSE = 1947.31
# Iteration #410: W_new = [1.96086146 3.64472756], MSE = 1945.74
# Iteration #420: W_new = [1.96245368 3.64955258], MSE = 1944.31
# Iteration #430: W_new = [1.96390063 3.6539362 ], MSE = 1943.02
# Iteration #440: W_new = [1.96521562 3.65791902], MSE = 1941.84
# Iteration #450: W_new = [1.96641072 3.66153789], MSE = 1940.77
# Iteration #460: W_new = [1.96749688 3.66482621], MSE = 1939.8
# Iteration #470: W_new = [1.96848407 3.6678143 ], MSE = 1938.92
# Iteration #480: W_new = [1.96938131 3.67052969], MSE = 1938.12
# Iteration #490: W_new = [1.97019682 3.67299735], MSE = 1937.39
# Iteration #0: W_new = [1.0108 0.5377], MSE = 3047.75
# Iteration #10: W_new = [1.10784583 0.87425489], MSE = 2910.74
# Iteration #20: W_new = [1.19433808 1.17081028], MSE = 2793.57
# Iteration #30: W_new = [1.27157753 1.43285993], MSE = 2692.81
# Iteration #40: W_new = [1.34067642 1.66501505], MSE = 2605.72
# Iteration #50: W_new = [1.40259086 1.87116766], MSE = 2530.09
# Iteration #60: W_new = [1.45814668 2.05462009], MSE = 2464.14
# Iteration #70: W_new = [1.50806047 2.21818819], MSE = 2406.41
# Iteration #80: W_new = [1.55295649 2.36428416], MSE = 2355.7
# Iteration #90: W_new = [1.59338065 2.49498341], MSE = 2311.02
# Iteration #100: W_new = [1.629812   2.61207894], MSE = 2271.54
# Iteration #110: W_new = [1.66267221 2.71712571], MSE = 2236.56
# Iteration #120: W_new = [1.69233352 2.81147704], MSE = 2205.5
# Iteration #130: W_new = [1.7191254  2.89631477], MSE = 2177.86
# Iteration #140: W_new = [1.74334016 2.9726742 ], MSE = 2153.21
# Iteration #150: W_new = [1.76523771 3.04146487], MSE = 2131.19
# Iteration #160: W_new = [1.78504962 3.10348806], MSE = 2111.49
# Iteration #170: W_new = [1.80298257 3.15945145], MSE = 2093.84
# Iteration #180: W_new = [1.81922132 3.2099815 ], MSE = 2078.01
# Iteration #190: W_new = [1.83393132 3.25563396], MSE = 2063.78
# Iteration #200: W_new = [1.8472609 3.2969029], MSE = 2050.99
# Iteration #210: W_new = [1.85934324 3.33422833], MSE = 2039.48
# Iteration #220: W_new = [1.87029801 3.3680028 ], MSE = 2029.11
# Iteration #230: W_new = [1.88023288 3.39857706], MSE = 2019.76
# Iteration #240: W_new = [1.88924481 3.42626499], MSE = 2011.32
# Iteration #250: W_new = [1.8974212  3.45134785], MSE = 2003.7
# Iteration #260: W_new = [1.90484088 3.47407798], MSE = 1996.81
# Iteration #270: W_new = [1.91157499 3.49468201], MSE = 1990.59
# Iteration #280: W_new = [1.9176878  3.51336372], MSE = 1984.96
# Iteration #290: W_new = [1.92323739 3.53030652], MSE = 1979.86
# Iteration #300: W_new = [1.92827628 3.5456756 ], MSE = 1975.25
# Iteration #310: W_new = [1.93285198 3.5596199 ], MSE = 1971.07
# Iteration #320: W_new = [1.9370075  3.57227376], MSE = 1967.29
# Iteration #330: W_new = [1.94078177 3.5837585 ], MSE = 1963.86
# Iteration #340: W_new = [1.94421005 3.59418366], MSE = 1960.75
# Iteration #350: W_new = [1.9473243 3.6036483], MSE = 1957.94
# Iteration #360: W_new = [1.95015349 3.61224195], MSE = 1955.38
# Iteration #370: W_new = [1.95272386 3.62004565], MSE = 1953.06
# Iteration #380: W_new = [1.95505923 3.62713272], MSE = 1950.96
# Iteration #390: W_new = [1.9571812  3.63356957], MSE = 1949.05
# Iteration #400: W_new = [1.95910935 3.63941635], MSE = 1947.31
# Iteration #410: W_new = [1.96086146 3.64472756], MSE = 1945.74
# Iteration #420: W_new = [1.96245368 3.64955258], MSE = 1944.31
# Iteration #430: W_new = [1.96390063 3.6539362 ], MSE = 1943.02
# Iteration #440: W_new = [1.96521562 3.65791902], MSE = 1941.84
# Iteration #450: W_new = [1.96641072 3.66153789], MSE = 1940.77
# Iteration #460: W_new = [1.96749688 3.66482621], MSE = 1939.8
# Iteration #470: W_new = [1.96848407 3.6678143 ], MSE = 1938.92
# Iteration #480: W_new = [1.96938131 3.67052969], MSE = 1938.12
# Iteration #490: W_new = [1.97019682 3.67299735], MSE = 1937.39
# Iteration #500: W_new = [1.97093806 3.67523995], MSE = 1936.73
# Iteration #510: W_new = [1.97161181 3.67727807], MSE = 1936.12
# Iteration #520: W_new = [1.97222421 3.67913042], MSE = 1935.58
# Iteration #530: W_new = [1.97278086 3.68081396], MSE = 1935.08
# Iteration #540: W_new = [1.97328685 3.68234412], MSE = 1934.63
# Iteration #550: W_new = [1.97374679 3.68373489], MSE = 1934.22
# Iteration #560: W_new = [1.97416487 3.684999  ], MSE = 1933.85
# Iteration #570: W_new = [1.97454491 3.686148  ], MSE = 1933.51
# Iteration #580: W_new = [1.97489037 3.68719238], MSE = 1933.2
# Iteration #590: W_new = [1.9752044  3.68814169], MSE = 1932.92
# Iteration #600: W_new = [1.97548986 3.68900459], MSE = 1932.67
# Iteration #610: W_new = [1.97574936 3.68978896], MSE = 1932.44
# Iteration #620: W_new = [1.97598525 3.69050195], MSE = 1932.23
# Iteration #630: W_new = [1.97619968 3.69115006], MSE = 1932.04
# Iteration #640: W_new = [1.97639462 3.6917392 ], MSE = 1931.86
# Iteration #650: W_new = [1.97657182 3.69227474], MSE = 1931.71
# Iteration #660: W_new = [1.97673291 3.69276157], MSE = 1931.56
# Iteration #670: W_new = [1.97687934 3.6932041 ], MSE = 1931.43
# Iteration #680: W_new = [1.97701246 3.69360639], MSE = 1931.32
# Iteration #690: W_new = [1.97713348 3.69397208], MSE = 1931.21
# Iteration #700: W_new = [1.97724349 3.69430451], MSE = 1931.11
# Iteration #710: W_new = [1.9773435  3.69460671], MSE = 1931.02
# Iteration #720: W_new = [1.97743441 3.69488142], MSE = 1930.94
# Iteration #730: W_new = [1.97751706 3.69513115], MSE = 1930.87
# Iteration #740: W_new = [1.97759219 3.69535817], MSE = 1930.8
# Iteration #750: W_new = [1.97766049 3.69556455], MSE = 1930.74
# Iteration #760: W_new = [1.97772258 3.69575216], MSE = 1930.68
# Iteration #770: W_new = [1.97777903 3.69592271], MSE = 1930.63
# Iteration #780: W_new = [1.97783034 3.69607775], MSE = 1930.59
# Iteration #790: W_new = [1.97787699 3.69621869], MSE = 1930.55
# Iteration #0: W_new = [1.0108 0.5377], MSE = 3047.75
# Iteration #10: W_new = [1.10784583 0.87425489], MSE = 2910.74
# Iteration #20: W_new = [1.19433808 1.17081028], MSE = 2793.57
# Iteration #30: W_new = [1.27157753 1.43285993], MSE = 2692.81
# Iteration #40: W_new = [1.34067642 1.66501505], MSE = 2605.72
# Iteration #50: W_new = [1.40259086 1.87116766], MSE = 2530.09
# Iteration #60: W_new = [1.45814668 2.05462009], MSE = 2464.14
# Iteration #70: W_new = [1.50806047 2.21818819], MSE = 2406.41
# Iteration #80: W_new = [1.55295649 2.36428416], MSE = 2355.7
# Iteration #90: W_new = [1.59338065 2.49498341], MSE = 2311.02
# Iteration #100: W_new = [1.629812   2.61207894], MSE = 2271.54
# Iteration #110: W_new = [1.66267221 2.71712571], MSE = 2236.56
# Iteration #120: W_new = [1.69233352 2.81147704], MSE = 2205.5
# Iteration #130: W_new = [1.7191254  2.89631477], MSE = 2177.86
# Iteration #140: W_new = [1.74334016 2.9726742 ], MSE = 2153.21
# Iteration #150: W_new = [1.76523771 3.04146487], MSE = 2131.19
# Iteration #160: W_new = [1.78504962 3.10348806], MSE = 2111.49
# Iteration #170: W_new = [1.80298257 3.15945145], MSE = 2093.84
# Iteration #180: W_new = [1.81922132 3.2099815 ], MSE = 2078.01
# Iteration #190: W_new = [1.83393132 3.25563396], MSE = 2063.78
# Iteration #200: W_new = [1.8472609 3.2969029], MSE = 2050.99
# Iteration #210: W_new = [1.85934324 3.33422833], MSE = 2039.48
# Iteration #220: W_new = [1.87029801 3.3680028 ], MSE = 2029.11
# Iteration #230: W_new = [1.88023288 3.39857706], MSE = 2019.76
# Iteration #240: W_new = [1.88924481 3.42626499], MSE = 2011.32
# Iteration #250: W_new = [1.8974212  3.45134785], MSE = 2003.7
# Iteration #260: W_new = [1.90484088 3.47407798], MSE = 1996.81
# Iteration #270: W_new = [1.91157499 3.49468201], MSE = 1990.59
# Iteration #280: W_new = [1.9176878  3.51336372], MSE = 1984.96
# Iteration #290: W_new = [1.92323739 3.53030652], MSE = 1979.86
# Iteration #300: W_new = [1.92827628 3.5456756 ], MSE = 1975.25
# Iteration #310: W_new = [1.93285198 3.5596199 ], MSE = 1971.07
# Iteration #320: W_new = [1.9370075  3.57227376], MSE = 1967.29
# Iteration #330: W_new = [1.94078177 3.5837585 ], MSE = 1963.86
# Iteration #340: W_new = [1.94421005 3.59418366], MSE = 1960.75
# Iteration #350: W_new = [1.9473243 3.6036483], MSE = 1957.94
# Iteration #360: W_new = [1.95015349 3.61224195], MSE = 1955.38
# Iteration #370: W_new = [1.95272386 3.62004565], MSE = 1953.06
# Iteration #380: W_new = [1.95505923 3.62713272], MSE = 1950.96
# Iteration #390: W_new = [1.9571812  3.63356957], MSE = 1949.05
# Iteration #400: W_new = [1.95910935 3.63941635], MSE = 1947.31
# Iteration #410: W_new = [1.96086146 3.64472756], MSE = 1945.74
# Iteration #420: W_new = [1.96245368 3.64955258], MSE = 1944.31
# Iteration #430: W_new = [1.96390063 3.6539362 ], MSE = 1943.02
# Iteration #440: W_new = [1.96521562 3.65791902], MSE = 1941.84
# Iteration #450: W_new = [1.96641072 3.66153789], MSE = 1940.77
# Iteration #460: W_new = [1.96749688 3.66482621], MSE = 1939.8
# Iteration #470: W_new = [1.96848407 3.6678143 ], MSE = 1938.92
# Iteration #480: W_new = [1.96938131 3.67052969], MSE = 1938.12
# Iteration #490: W_new = [1.97019682 3.67299735], MSE = 1937.39
# Iteration #500: W_new = [1.97093806 3.67523995], MSE = 1936.73
# Iteration #510: W_new = [1.97161181 3.67727807], MSE = 1936.12
# Iteration #520: W_new = [1.97222421 3.67913042], MSE = 1935.58
# Iteration #530: W_new = [1.97278086 3.68081396], MSE = 1935.08
# Iteration #540: W_new = [1.97328685 3.68234412], MSE = 1934.63
# Iteration #550: W_new = [1.97374679 3.68373489], MSE = 1934.22
# Iteration #560: W_new = [1.97416487 3.684999  ], MSE = 1933.85
# Iteration #570: W_new = [1.97454491 3.686148  ], MSE = 1933.51
# Iteration #580: W_new = [1.97489037 3.68719238], MSE = 1933.2
# Iteration #590: W_new = [1.9752044  3.68814169], MSE = 1932.92
# Iteration #600: W_new = [1.97548986 3.68900459], MSE = 1932.67
# Iteration #610: W_new = [1.97574936 3.68978896], MSE = 1932.44
# Iteration #620: W_new = [1.97598525 3.69050195], MSE = 1932.23
# Iteration #630: W_new = [1.97619968 3.69115006], MSE = 1932.04
# Iteration #640: W_new = [1.97639462 3.6917392 ], MSE = 1931.86
# Iteration #650: W_new = [1.97657182 3.69227474], MSE = 1931.71
# Iteration #660: W_new = [1.97673291 3.69276157], MSE = 1931.56
# Iteration #670: W_new = [1.97687934 3.6932041 ], MSE = 1931.43
# Iteration #680: W_new = [1.97701246 3.69360639], MSE = 1931.32
# Iteration #690: W_new = [1.97713348 3.69397208], MSE = 1931.21
# Iteration #700: W_new = [1.97724349 3.69430451], MSE = 1931.11
# Iteration #710: W_new = [1.9773435  3.69460671], MSE = 1931.02
# Iteration #720: W_new = [1.97743441 3.69488142], MSE = 1930.94
# Iteration #730: W_new = [1.97751706 3.69513115], MSE = 1930.87
# Iteration #740: W_new = [1.97759219 3.69535817], MSE = 1930.8
# Iteration #750: W_new = [1.97766049 3.69556455], MSE = 1930.74
# Iteration #760: W_new = [1.97772258 3.69575216], MSE = 1930.68
# Iteration #770: W_new = [1.97777903 3.69592271], MSE = 1930.63
# Iteration #780: W_new = [1.97783034 3.69607775], MSE = 1930.59
# Iteration #790: W_new = [1.97787699 3.69621869], MSE = 1930.55
# Iteration #800: W_new = [1.9779194  3.69634682], MSE = 1930.51
# Iteration #810: W_new = [1.97795795 3.6964633 ], MSE = 1930.48
# Iteration #820: W_new = [1.977993   3.69656919], MSE = 1930.44
# Iteration #830: W_new = [1.97802486 3.69666545], MSE = 1930.42
# Iteration #840: W_new = [1.97805382 3.69675296], MSE = 1930.39
# Iteration #850: W_new = [1.97808015 3.69683251], MSE = 1930.37
# Iteration #860: W_new = [1.97810409 3.69690483], MSE = 1930.35
# Iteration #870: W_new = [1.97812585 3.69697058], MSE = 1930.33
# Iteration #880: W_new = [1.97814563 3.69703034], MSE = 1930.31
# Iteration #890: W_new = [1.97816361 3.69708468], MSE = 1930.29
# Iteration #900: W_new = [1.97817996 3.69713407], MSE = 1930.28
# Iteration #910: W_new = [1.97819483 3.69717897], MSE = 1930.26
# Iteration #920: W_new = [1.97820834 3.69721979], MSE = 1930.25
# Iteration #930: W_new = [1.97822062 3.6972569 ], MSE = 1930.24
# Iteration #940: W_new = [1.97823179 3.69729064], MSE = 1930.23
# Iteration #950: W_new = [1.97824194 3.69732131], MSE = 1930.22
# Iteration #960: W_new = [1.97825117 3.69734919], MSE = 1930.21
# Iteration #970: W_new = [1.97825955 3.69737453], MSE = 1930.21
# Iteration #980: W_new = [1.97826718 3.69739757], MSE = 1930.2
# Iteration #990: W_new = [1.97827411 3.69741852], MSE = 1930.19
# Лучшая ошибка 43.96875547135349 с параметрами {'alpha': 0.1, 'n_iter': 1000}

# %% [markdown]
# ### 2*. В этом коде мы избавляемся от итераций по весам, но тут есть ошибка, исправьте ее
# ___

# %%
n = X.shape[0]

alpha = 1e-2
n_iter = 700

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {alpha} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= alpha * (1/n * 2 * X[:, k] @ (y_pred - y))

    # Две строки выше поменяли на строку ниже:
    W -= alpha * (1/n * 2 * np.dot(X.T, y_pred - y))
    #
    if i % 100 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #100: W_new = [28.38281518  6.83710367], MSE = 177.43
# Iteration #200: W_new = [38.38986469  5.02247953], MSE = 65.33
# Iteration #300: W_new = [42.39314129  4.29654705], MSE = 47.39
# Iteration #400: W_new = [43.99463466  4.00614091], MSE = 44.52
# Iteration #500: W_new = [44.63530512  3.8899652 ], MSE = 44.06
# Iteration #600: W_new = [44.89160255  3.84348962], MSE = 43.98

# %% [markdown]
# ### 3. Вместо того, чтобы задавать количество итераций, задайте другое условие останова алгоритма - когда веса перестают изменяться меньше определенного порога — упрощённый аналог параметра tol в линейной регрессии в sklearn.
# ___

# %%
weights0 = np.array([1, 0.5])
weights1 = np.array([5, 1.9])
np.linalg.norm(weights0 - weights1, ord=2)
# Out:
# 4.237924020083418

# %%
import matplotlib.pyplot as plt

def plot_vectors(a, b):
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot([a[0]], [a[1]], '*')
    ax.plot([b[0]], [b[1]], '+')
    ax.set_xlabel('intercept')
    ax.set_ylabel('w1')
    return ax

# %%
ax = plot_vectors(weights0, weights1)
ax.plot([weights0[0], weights1[0]], [weights0[1], weights1[1]]);

# %%
# a**2 + b**2 = c**2
((5-1)**2 + (1.9-0.5)**2)**0.5
# Out:
# 4.237924020083418

# %%
ax = plot_vectors(weights0, weights1)
ax.plot([weights0[0], weights1[0]], [weights0[1], weights0[1]], c='r')
ax.plot([weights1[0], weights1[0]], [weights0[1], weights1[1]], c='r');

# %%
np.linalg.norm(weights0 - weights1, ord=1)
# Out:
# 5.4

# %%
abs(5-1) + abs(1.9-0.5)
# Out:
# 5.4

# %%
n = X.shape[0]

eta = 1e-2 
epsilon = 1e-8
iter_num = 0

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')
weight_dist = np.inf

while weight_dist > epsilon:
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)

    W_new = W - eta * (1/n * 2 * np.dot(X.T, y_pred - y))
    weight_dist = np.linalg.norm(W_new - W, ord=2)
    W = W_new.copy()
    
    if iter_num % 10 == 0:
        print(f'Iteration #{iter_num}: W_new = {W}, MSE = {round(err,2)}')
    iter_num += 1
print(f'Порог равен: {epsilon}, изменение весов составляет: {weight_dist}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 7.0011236 10.6169007], MSE = 738.65
# Iteration #20: W_new = [10.3486292  10.10603105], MSE = 622.03
# Iteration #30: W_new = [13.38789582  9.55618391], MSE = 525.24
# Iteration #40: W_new = [16.16088505  9.05336203], MSE = 444.66
# Iteration #50: W_new = [18.69110735  8.59454545], MSE = 377.58
# Iteration #60: W_new = [20.99981865  8.17589626], MSE = 321.72
# Iteration #70: W_new = [23.10641138  7.79389815], MSE = 275.22
# Iteration #80: W_new = [25.02858024  7.44534246], MSE = 236.5
# Iteration #90: W_new = [26.78247081  7.12730145], MSE = 204.27
# Iteration #100: W_new = [28.38281518  6.83710367], MSE = 177.43
# Iteration #110: W_new = [29.84305573  6.57231156], MSE = 155.08
# Iteration #120: W_new = [31.17545797  6.33070096], MSE = 136.48
# Iteration #130: W_new = [32.39121367  6.11024241], MSE = 120.99
# Iteration #140: W_new = [33.50053475  5.90908413], MSE = 108.09
# Iteration #150: W_new = [34.51273915  5.72553647], MSE = 97.36
# Iteration #160: W_new = [35.43632906  5.55805768], MSE = 88.42
# Iteration #170: W_new = [36.27906231  5.405241  ], MSE = 80.98
# Iteration #180: W_new = [37.0480176   5.26580281], MSE = 74.78
# Iteration #190: W_new = [37.74965389  5.13857189], MSE = 69.62
# Iteration #200: W_new = [38.38986469  5.02247953], MSE = 65.33
# Iteration #210: W_new = [38.97402756  4.9165506 ], MSE = 61.75
# Iteration #220: W_new = [39.50704928  4.81989533], MSE = 58.77
# Iteration #230: W_new = [39.99340705  4.73170185], MSE = 56.29
# Iteration #240: W_new = [40.43718613  4.65122936], MSE = 54.23
# Iteration #250: W_new = [40.84211409  4.57780191], MSE = 52.51
# Iteration #260: W_new = [41.21159221  4.51080275], MSE = 51.08
# Iteration #270: W_new = [41.54872398  4.4496691 ], MSE = 49.89
# Iteration #280: W_new = [41.8563412   4.39388747], MSE = 48.9
# Iteration #290: W_new = [42.13702774  4.34298929], MSE = 48.07
# Iteration #300: W_new = [42.39314129  4.29654705], MSE = 47.39
# Iteration #310: W_new = [42.6268331   4.25417064], MSE = 46.81
# Iteration #320: W_new = [42.84006612  4.21550412], MSE = 46.34
# Iteration #330: W_new = [43.03463143  4.1802227 ], MSE = 45.94
# Iteration #340: W_new = [43.21216332  4.14803003], MSE = 45.61
# Iteration #350: W_new = [43.37415299  4.1186557 ], MSE = 45.34
# Iteration #360: W_new = [43.5219611   4.09185298], MSE = 45.11
# Iteration #370: W_new = [43.6568292   4.06739673], MSE = 44.92
# Iteration #380: W_new = [43.77989013  4.04508153], MSE = 44.76
# Iteration #390: W_new = [43.89217756  4.02471993], MSE = 44.63
# Iteration #400: W_new = [43.99463466  4.00614091], MSE = 44.52
# Iteration #410: W_new = [44.08812206  3.98918842], MSE = 44.42
# Iteration #420: W_new = [44.173425    3.97372004], MSE = 44.35
# Iteration #430: W_new = [44.25126001  3.95960587], MSE = 44.28
# Iteration #440: W_new = [44.32228086  3.94672733], MSE = 44.23
# Iteration #450: W_new = [44.38708413  3.93497626], MSE = 44.19
# Iteration #460: W_new = [44.44621412  3.92425394], MSE = 44.15
# Iteration #470: W_new = [44.50016751  3.91447033], MSE = 44.12
# Iteration #480: W_new = [44.5493975   3.90554323], MSE = 44.1
# Iteration #490: W_new = [44.5943176   3.89739766], MSE = 44.07
# Iteration #500: W_new = [44.63530512  3.8899652 ], MSE = 44.06
# Iteration #510: W_new = [44.67270435  3.88318343], MSE = 44.04
# Iteration #520: W_new = [44.70682942  3.87699538], MSE = 44.03
# Iteration #530: W_new = [44.73796697  3.87134906], MSE = 44.02
# Iteration #540: W_new = [44.76637856  3.86619706], MSE = 44.01
# Iteration #550: W_new = [44.79230282  3.86149609], MSE = 44.0
# Iteration #560: W_new = [44.81595752  3.85720668], MSE = 44.0
# Iteration #570: W_new = [44.83754134  3.85329279], MSE = 43.99
# Iteration #580: W_new = [44.85723558  3.84972154], MSE = 43.99
# Iteration #590: W_new = [44.87520567  3.84646294], MSE = 43.99
# Iteration #600: W_new = [44.89160255  3.84348962], MSE = 43.98
# Iteration #610: W_new = [44.90656394  3.8407766 ], MSE = 43.98
# Iteration #620: W_new = [44.92021553  3.83830109], MSE = 43.98
# Iteration #630: W_new = [44.93267197  3.83604231], MSE = 43.98
# Iteration #640: W_new = [44.94403791  3.83398127], MSE = 43.98
# Iteration #650: W_new = [44.95440879  3.83210067], MSE = 43.97
# Iteration #660: W_new = [44.96387175  3.83038471], MSE = 43.97
# Iteration #670: W_new = [44.97250627  3.82881898], MSE = 43.97
# Iteration #680: W_new = [44.98038486  3.82739031], MSE = 43.97
# Iteration #690: W_new = [44.98757372  3.82608673], MSE = 43.97
# Iteration #700: W_new = [44.99413322  3.82489726], MSE = 43.97
# Iteration #710: W_new = [45.00011846  3.82381193], MSE = 43.97
# Iteration #720: W_new = [45.00557972  3.82282162], MSE = 43.97
# Iteration #730: W_new = [45.01056286  3.821918  ], MSE = 43.97
# Iteration #740: W_new = [45.01510975  3.82109349], MSE = 43.97
# Iteration #750: W_new = [45.01925858  3.82034116], MSE = 43.97
# Iteration #760: W_new = [45.0230442  3.8196547], MSE = 43.97
# Iteration #770: W_new = [45.0264984   3.81902834], MSE = 43.97
# Iteration #780: W_new = [45.0296502   3.81845681], MSE = 43.97
# Iteration #790: W_new = [45.03252607  3.81793531], MSE = 43.97
# Iteration #800: W_new = [45.03515017  3.81745947], MSE = 43.97
# Iteration #810: W_new = [45.03754454  3.81702529], MSE = 43.97
# Iteration #820: W_new = [45.03972929  3.81662912], MSE = 43.97
# Iteration #830: W_new = [45.04172277  3.81626763], MSE = 43.97
# Iteration #840: W_new = [45.04354174  3.81593779], MSE = 43.97
# Iteration #850: W_new = [45.04520146  3.81563682], MSE = 43.97
# Iteration #860: W_new = [45.04671588  3.81536221], MSE = 43.97
# Iteration #870: W_new = [45.04809772  3.81511163], MSE = 43.97
# Iteration #880: W_new = [45.04935858  3.81488299], MSE = 43.97
# Iteration #890: W_new = [45.05050906  3.81467437], MSE = 43.97
# Iteration #900: W_new = [45.05155882  3.81448401], MSE = 43.97
# Iteration #910: W_new = [45.05251668  3.81431032], MSE = 43.97
# Iteration #920: W_new = [45.05339068  3.81415184], MSE = 43.97
# Iteration #930: W_new = [45.05418816  3.81400722], MSE = 43.97
# Iteration #940: W_new = [45.05491583  3.81387527], MSE = 43.97
# Iteration #950: W_new = [45.05557979  3.81375487], MSE = 43.97
# Iteration #960: W_new = [45.05618563  3.81364501], MSE = 43.97
# Iteration #970: W_new = [45.05673843  3.81354477], MSE = 43.97
# Iteration #980: W_new = [45.05724283  3.81345331], MSE = 43.97
# Iteration #990: W_new = [45.05770308  3.81336985], MSE = 43.97
# Iteration #1000: W_new = [45.05812303  3.8132937 ], MSE = 43.97
# Iteration #1010: W_new = [45.05850621  3.81322421], MSE = 43.97
# Iteration #1020: W_new = [45.05885585  3.81316081], MSE = 43.97
# Iteration #1030: W_new = [45.05917489  3.81310296], MSE = 43.97
# Iteration #1040: W_new = [45.05946599  3.81305017], MSE = 43.97
# Iteration #1050: W_new = [45.0597316   3.81300201], MSE = 43.97
# Iteration #1060: W_new = [45.05997396  3.81295806], MSE = 43.97
# Iteration #1070: W_new = [45.06019511  3.81291796], MSE = 43.97
# Iteration #1080: W_new = [45.06039689  3.81288137], MSE = 43.97
# Iteration #1090: W_new = [45.06058101  3.81284798], MSE = 43.97
# Iteration #1100: W_new = [45.06074901  3.81281751], MSE = 43.97
# Iteration #1110: W_new = [45.0609023   3.81278972], MSE = 43.97
# Iteration #1120: W_new = [45.06104218  3.81276435], MSE = 43.97
# Iteration #1130: W_new = [45.0611698   3.81274121], MSE = 43.97
# Iteration #1140: W_new = [45.06128626  3.81272009], MSE = 43.97
# Iteration #1150: W_new = [45.06139251  3.81270083], MSE = 43.97
# Iteration #1160: W_new = [45.06148947  3.81268324], MSE = 43.97
# Iteration #1170: W_new = [45.06157794  3.8126672 ], MSE = 43.97
# Iteration #1180: W_new = [45.06165866  3.81265256], MSE = 43.97
# Iteration #1190: W_new = [45.06173232  3.81263921], MSE = 43.97
# Iteration #1200: W_new = [45.06179952  3.81262702], MSE = 43.97
# Iteration #1210: W_new = [45.06186085  3.8126159 ], MSE = 43.97
# Iteration #1220: W_new = [45.0619168   3.81260575], MSE = 43.97
# Iteration #1230: W_new = [45.06196786  3.8125965 ], MSE = 43.97
# Iteration #1240: W_new = [45.06201445  3.81258805], MSE = 43.97
# Iteration #1250: W_new = [45.06205696  3.81258034], MSE = 43.97
# Iteration #1260: W_new = [45.06209574  3.81257331], MSE = 43.97
# Iteration #1270: W_new = [45.06213113  3.81256689], MSE = 43.97
# Iteration #1280: W_new = [45.06216343  3.81256103], MSE = 43.97
# Iteration #1290: W_new = [45.06219289  3.81255569], MSE = 43.97
# Iteration #1300: W_new = [45.06221978  3.81255081], MSE = 43.97
# Iteration #1310: W_new = [45.06224431  3.81254637], MSE = 43.97
# Iteration #1320: W_new = [45.06226669  3.81254231], MSE = 43.97
# Iteration #1330: W_new = [45.06228712  3.8125386 ], MSE = 43.97
# Iteration #1340: W_new = [45.06230576  3.81253522], MSE = 43.97
# Iteration #1350: W_new = [45.06232276  3.81253214], MSE = 43.97
# Iteration #1360: W_new = [45.06233828  3.81252933], MSE = 43.97
# Iteration #1370: W_new = [45.06235244  3.81252676], MSE = 43.97
# Iteration #1380: W_new = [45.06236536  3.81252442], MSE = 43.97
# Iteration #1390: W_new = [45.06237714  3.81252228], MSE = 43.97
# Iteration #1400: W_new = [45.0623879   3.81252033], MSE = 43.97
# Iteration #1410: W_new = [45.06239771  3.81251855], MSE = 43.97
# Iteration #1420: W_new = [45.06240667  3.81251692], MSE = 43.97
# Iteration #1430: W_new = [45.06241484  3.81251544], MSE = 43.97
# Iteration #1440: W_new = [45.06242229  3.81251409], MSE = 43.97
# Iteration #1450: W_new = [45.0624291   3.81251286], MSE = 43.97
# Iteration #1460: W_new = [45.0624353   3.81251173], MSE = 43.97
# Iteration #1470: W_new = [45.06244097  3.8125107 ], MSE = 43.97
# Iteration #1480: W_new = [45.06244614  3.81250977], MSE = 43.97
# Iteration #1490: W_new = [45.06245085  3.81250891], MSE = 43.97
# Iteration #1500: W_new = [45.06245515  3.81250813], MSE = 43.97
# Iteration #1510: W_new = [45.06245908  3.81250742], MSE = 43.97
# Iteration #1520: W_new = [45.06246266  3.81250677], MSE = 43.97
# Iteration #1530: W_new = [45.06246593  3.81250618], MSE = 43.97
# Iteration #1540: W_new = [45.06246891  3.81250564], MSE = 43.97
# Iteration #1550: W_new = [45.06247164  3.81250514], MSE = 43.97
# Iteration #1560: W_new = [45.06247412  3.81250469], MSE = 43.97
# Iteration #1570: W_new = [45.06247638  3.81250428], MSE = 43.97
# Iteration #1580: W_new = [45.06247845  3.81250391], MSE = 43.97
# Iteration #1590: W_new = [45.06248034  3.81250357], MSE = 43.97
# Iteration #1600: W_new = [45.06248206  3.81250325], MSE = 43.97
# Iteration #1610: W_new = [45.06248363  3.81250297], MSE = 43.97
# Iteration #1620: W_new = [45.06248506  3.81250271], MSE = 43.97
# Iteration #1630: W_new = [45.06248637  3.81250247], MSE = 43.97
# Iteration #1640: W_new = [45.06248756  3.81250226], MSE = 43.97
# Iteration #1650: W_new = [45.06248865  3.81250206], MSE = 43.97
# Iteration #1660: W_new = [45.06248965  3.81250188], MSE = 43.97
# Iteration #1670: W_new = [45.06249055  3.81250171], MSE = 43.97
# Iteration #1680: W_new = [45.06249138  3.81250156], MSE = 43.97
# Iteration #1690: W_new = [45.06249213  3.81250143], MSE = 43.97
# Iteration #1700: W_new = [45.06249282  3.8125013 ], MSE = 43.97
# Iteration #1710: W_new = [45.06249345  3.81250119], MSE = 43.97
# Iteration #1720: W_new = [45.06249402  3.81250108], MSE = 43.97
# Iteration #1730: W_new = [45.06249455  3.81250099], MSE = 43.97
# Iteration #1740: W_new = [45.06249503  3.8125009 ], MSE = 43.97
# Iteration #1750: W_new = [45.06249546  3.81250082], MSE = 43.97
# Iteration #1760: W_new = [45.06249586  3.81250075], MSE = 43.97
# Iteration #1770: W_new = [45.06249622  3.81250069], MSE = 43.97
# Iteration #1780: W_new = [45.06249655  3.81250063], MSE = 43.97
# Iteration #1790: W_new = [45.06249685  3.81250057], MSE = 43.97
# Iteration #1800: W_new = [45.06249713  3.81250052], MSE = 43.97
# Iteration #1810: W_new = [45.06249738  3.81250048], MSE = 43.97
# Iteration #1820: W_new = [45.06249761  3.81250043], MSE = 43.97
# Iteration #1830: W_new = [45.06249782  3.8125004 ], MSE = 43.97
# Iteration #1840: W_new = [45.06249801  3.81250036], MSE = 43.97
# Iteration #1850: W_new = [45.06249818  3.81250033], MSE = 43.97
# Iteration #1860: W_new = [45.06249834  3.8125003 ], MSE = 43.97
# Iteration #1870: W_new = [45.06249849  3.81250027], MSE = 43.97
# Iteration #1880: W_new = [45.06249862  3.81250025], MSE = 43.97
# Iteration #1890: W_new = [45.06249874  3.81250023], MSE = 43.97
# Iteration #1900: W_new = [45.06249885  3.81250021], MSE = 43.97
# Порог равен: 1e-08, изменение весов составляет: 9.984448881260898e-09
